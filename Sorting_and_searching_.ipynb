# %%
Def selection_sort(X,n):
	for i in range(n-1):
		min_index = i
		for j in range( i,n):
			if X[j] < X[min_index]:
				min_index = j
		X[i], X[min_index] = X[min_index], X[i]


Def insertion_sort(X,n):
	for i in range(1,n):
		curr_value = X[i]
		j =  i - 1
		while j >= 0 and X[j] > curr_value:
			X[j + 1] = X[j]
			j = j - 1
		X[j + 1] = curr_value

# pseudocode

Merge_sort(A,start,end)
	if start >= end
		return
	mid = (start+end)/2
	merge_sort(A,start,mid)
	merge_sort(A,mid+1,end)
	merge(A, start, mid, end)

Merge(A, start, mid, end)
	nL = mid - start + 1
	nR = end - mid
	let L[0: nL - 1] and R[0: nR - 1] be new arrays
	for i = 0 to nL - 1
		L[i] = A[start + i]
	for j = 0 to nR - 1
		R[j] = A[mid + j + 1]
	i = 0
	j = 0
	k = start

	while i < nL and j < nR
		if L[i] <= R[j]
			A[k] = L[i]
			i = i + 1
		else A[k] = R[j]
			j = j + 1
		k = k + 1

	while i < nL
		A[k] = L[i]
		i = i + 1
		k = k + 1

	while j < nR
		A[k] = R[j]
		j = j + 1
		j = k + 1

Quicksort(A, start, end)
	if start < end
	pivot = partition(A, start, end)
	quicksort(A, start, pivot - 1)
	quicksort(A, pivot + 1, end)

Partition(A, start, end)
	x = A[end]
	i = start - 1
	for j = start to end-1
		if A[j] <= x
			i = i + 1
			exchange A[i] with A[j]
	exchange A[i+1] with A[end]
	return i + 1

BinarySearch(A[0…n-1], K)
l = 0
r = n - 1
while l <= r do
	m = (l+r)/2
	if K = A[m]
		return m
	else if K < A[m]
		r = m - 1
	else l = m + 1
return - 1

Recursive_BinarySearch(A, x, low, high)
	if low > high
		return NIL
	mid = (low+high)/2
	if x == A[mid]
		return mid
	elseif x > A[mid]
		return Recursive_BinarySearch(A, x, mid + 1, high)
	else return Recursive_BinarySearch(A, x, low, mid - 1)

Iterative_BinarySearch(A, x, low, high)
	while low <= high
		mid = (low+high)/2
		if x == A[mid]
			return mid
		elseif x > A[mid]
			low = mid + 1
		else high = mid - 1
	return NIL
